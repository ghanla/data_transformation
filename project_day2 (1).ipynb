# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
car_df = pd.read_csv('/aiffel/data/cars.csv')

# %%
brand_df = pd.read_csv('/aiffel/data/brand.csv')

# %%
car_df
# Out:
#                title  Price  Mileage(miles)  Registration_Year  \
# 0        SKODA FABIA   6900           70189               2016
# 1     VAUXHALL CORSA   1495           88585               2008
# 2        HYUNDAI I30    949          137000               2011
# 3         MINI HATCH   2395           96731               2010
# 4     VAUXHALL CORSA   1000           85000               2013
# ...              ...    ...             ...                ...
# 3682  RENAULT MEGANE   1395           76202               2006
# 3683         AUDI A4   6990          119000               2012
# 3684    BMW 3 SERIES   3995          139000               2013
# 3685    HONDA ACCORD   1390          179190               2007
# 3686  VAUXHALL CORSA   2000           82160               2013
#
#       Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0                 3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# ...

# %%
brand_df
# Out:
#             title         country
# 0           skoda  Czech Republic
# 1        vauxhall  United Kingdom
# 2         hyundai     South Korea
# 3            mini  United Kingdom
# 4            ford   United States
# 5           volvo          Sweden
# 6         peugeot          France
# 7             bmw         Germany
# 8         citroen          France
# 9   mercedes-benz         Germany
# 10          mazda           Japan
# 11           saab          Sweden
# 12     volkswagen         Germany
# 13          honda           Japan
# 14             mg  United Kingdom
# 15         toyota           Japan
# 16           seat           Spain
# 17         nissan           Japan
# 18           alfa           Italy
# 19        renault          France
# 20            kia     South Korea
# 21         proton        Malaysia
# 22           fiat           Italy
# 23           audi         Germany
# 24     mitsubishi           Japan
# 25          lexus           Japan
# ...

# %%
car_df['title'].unique()
# Out:
# array(['SKODA FABIA', 'VAUXHALL CORSA', 'HYUNDAI I30', 'MINI HATCH',
#        'HYUNDAI COUPE', 'FORD FOCUS', 'VOLVO 740', 'PEUGEOT 207',
#        'FORD FIESTA', 'VAUXHALL INSIGNIA', 'BMW 3 SERIES', 'CITROEN C1',
#        'CITROEN C4', 'VAUXHALL ASTRA', 'FORD MONDEO',
#        'MERCEDES-BENZ A180', 'PEUGEOT 407', 'FORD KA',
#        'MERCEDES-BENZ A CLASS', 'MAZDA MAZDA2', 'SAAB 9-3',
#        'VOLKSWAGEN POLO', 'BMW 1 SERIES', 'HONDA ACCORD',
#        'VOLKSWAGEN BEETLE', 'MG MG6', 'FORD C-MAX', 'HONDA CIVIC',
#        'TOYOTA AURIS', 'VOLVO S40', 'SEAT IBIZA', 'PEUGEOT 308',
#        'VAUXHALL MERIVA', 'MERCEDES-BENZ B CLASS', 'MAZDA MAZDA3',
#        'NISSAN 350 Z', 'ALFA ROMEO MITO', 'RENAULT FLUENCE',
#        'VOLKSWAGEN PASSAT', 'KIA SPORTAGE', 'CITROEN XM',
#        'VAUXHALL ANTARA', 'NISSAN NOTE', 'BMW 5 SERIES', 'HONDA CR-V',
#        'PROTON SAVVY', 'NISSAN MICRA', 'FIAT PANDA', 'RENAULT MEGANE',
#        'RENAULT CLIO', 'HYUNDAI I20', 'CITROEN C3', 'AUDI A6 SALOON',
# ...

# %%
brand_df['title'].unique()
# Out:
# array(['skoda', 'vauxhall', 'hyundai', 'mini', 'ford', 'volvo', 'peugeot',
#        'bmw', 'citroen', 'mercedes-benz', 'mazda', 'saab', 'volkswagen',
#        'honda', 'mg', 'toyota', 'seat', 'nissan', 'alfa', 'renault',
#        'kia', 'proton', 'fiat', 'audi', 'mitsubishi', 'lexus', 'land',
#        'chevrolet', 'suzuki', 'dacia', 'daihatsu', 'jeep', 'jaguar',
#        'chrysler', 'rover', 'ds', 'daewoo', 'dodge', 'porsche', 'subaru',
#        'infiniti', 'abarth', 'smart', 'marcos', 'maserati', 'ssangyong',
#        'lagonda', 'isuzu'], dtype=object)

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3687 entries, 0 to 3686
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   object
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   object
#  12  Service history    540 non-null    object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 374.6+ KB

# %%
car_df.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382696
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.012205
# Gearbox              0.000000
# Doors                0.006781
# Seats                0.009493
# Emission Class       0.023596
# Service history      0.853539
# dtype: float64

# %%
pd.DataFrame(car_df['title'].str.lower().str.split(' ',expand=True))
# Out:
#              0       1       2     3     4     5     6
# 0        skoda   fabia    None  None  None  None  None
# 1     vauxhall   corsa    None  None  None  None  None
# 2      hyundai     i30    None  None  None  None  None
# 3         mini   hatch    None  None  None  None  None
# 4     vauxhall   corsa    None  None  None  None  None
# ...        ...     ...     ...   ...   ...   ...   ...
# 3682   renault  megane    None  None  None  None  None
# 3683      audi      a4    None  None  None  None  None
# 3684       bmw       3  series  None  None  None  None
# 3685     honda  accord    None  None  None  None  None
# 3686  vauxhall   corsa    None  None  None  None  None
#
# [3687 rows x 7 columns]

# %%
t.isna().sum()
# Out:
# 0       0
# 1       0
# 2    2965
# 3    3592
# 4    3648
# 5    3683
# 6    3684
# dtype: int64

# %%
pd.concat([car_df, pd.DataFrame(car_df['title'].str.lower().str.split(' ', expand=True), index=car_df.index)])
# Out:
#              0       1       2     3     4     5     6  Body type  Doors  \
# 0          NaN     NaN     NaN   NaN   NaN   NaN   NaN  Hatchback    5.0
# 1          NaN     NaN     NaN   NaN   NaN   NaN   NaN  Hatchback    3.0
# 2          NaN     NaN     NaN   NaN   NaN   NaN   NaN  Hatchback    5.0
# 3          NaN     NaN     NaN   NaN   NaN   NaN   NaN  Hatchback    3.0
# 4          NaN     NaN     NaN   NaN   NaN   NaN   NaN  Hatchback    5.0
# ...        ...     ...     ...   ...   ...   ...   ...        ...    ...
# 3682   renault  megane    None  None  None  None  None        NaN    NaN
# 3683      audi      a4    None  None  None  None  None        NaN    NaN
# 3684       bmw       3  series  None  None  None  None        NaN    NaN
# 3685     honda  accord    None  None  None  None  None        NaN    NaN
# 3686  vauxhall   corsa    None  None  None  None  None        NaN    NaN
#
#      Emission Class Engine Fuel type Gearbox  Mileage(miles)  Previous Owners  \
# ...

# %%
tt = pd.DataFrame(car_df['title'].str.lower().str.split(expand=True),columns = [0])
tt = tt.rename(columns={tt.columns[0]: 'Title'})
tt
# Out:
#          Title
# 0        skoda
# 1     vauxhall
# 2      hyundai
# 3         mini
# 4     vauxhall
# ...        ...
# 3682   renault
# 3683      audi
# 3684       bmw
# 3685     honda
# 3686  vauxhall
#
# [3687 rows x 1 columns]

# %%
car_df = pd.concat([car_df, tt], axis = 1)

# %%
brand_df = brand_df.rename(columns={'title': 'Title'})

# %%
car_df.drop(['Title'], axis = 1, inplace = True)

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     Title
# 0             NaN     skoda
# 1            Full  vauxhall
# ...

# %%
car_brand_df = car_df.merge(brand_df, on = 'Title')

# %%
car_brand_df = car_brand_df.rename({'Title' : 'brand_title'},axis = 1) # 병합 완료

# %% [markdown]
# ### 이제 데이터 전처리 시작

# %%
car_brand_df
# Out:
#                       title  Price  Mileage(miles)  Registration_Year  \
# 0               SKODA FABIA   6900           70189               2016
# 1               SKODA FABIA   6900           70189               2016
# 2               SKODA FABIA   1990          150000               2007
# 3               SKODA FABIA   1995           84000               2008
# 4               SKODA FABIA   2495          124138               2011
# ...                     ...    ...             ...                ...
# 3682  MASERATI QUATTROPORTE  10000           72000               2009
# 3683      SSANGYONG KORANDO  12995           42771               2018
# 3684      SSANGYONG KORANDO   4277           82400               2013
# 3685   LAGONDA LG6 ROADSTER  14995           84000               1953
# 3686          ISUZU TROOPER   2250          147700               2001
#
#       Previous Owners Fuel type  Body type Engine    Gearbox  Doors  Seats  \
# ...

# %%
car_brand_df.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382696
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.012205
# Gearbox              0.000000
# Doors                0.006781
# Seats                0.009493
# Emission Class       0.023596
# Service history      0.853539
# brand_title          0.000000
# country              0.000000
# dtype: float64

# %%
car_brand_df.dropna(subset=['Seats'],inplace=True)

# %%
car_brand_df
# Out:
#                       title  Price  Mileage(miles)  Registration_Year  \
# 0               SKODA FABIA   6900           70189               2016
# 1               SKODA FABIA   6900           70189               2016
# 2               SKODA FABIA   1990          150000               2007
# 3               SKODA FABIA   1995           84000               2008
# 4               SKODA FABIA   2495          124138               2011
# ...                     ...    ...             ...                ...
# 3680   MASERATI GRANTURISMO  16000           66000               2008
# 3681        MASERATI GHIBLI  13900           63000               2014
# 3682  MASERATI QUATTROPORTE  10000           72000               2009
# 3683      SSANGYONG KORANDO  12995           42771               2018
# 3684      SSANGYONG KORANDO   4277           82400               2013
#
#       Previous Owners Fuel type  Body type Engine    Gearbox  Doors  Seats  \
# ...

# %%
car_brand_df.dropna(subset=['Doors'],inplace = True)

# %%
car_brand_df.dropna(subset=['Engine'],inplace = True)

# %%
car_brand_df.describe()
# Out:
#               Price  Mileage(miles)  Registration_Year  Previous Owners  \
# count   3607.000000    3.607000e+03        3607.000000      2248.000000
# mean    5790.819240    8.151754e+04        2011.942057         2.804715
# std     4508.595645    3.950285e+04           4.771858         1.545234
# min      400.000000    1.000000e+00        1987.000000         1.000000
# 25%     2490.000000    5.698400e+04        2008.000000         2.000000
# 50%     4000.000000    8.000000e+04        2012.000000         3.000000
# 75%     7999.000000    1.030495e+05        2016.000000         4.000000
# max    33900.000000    1.110100e+06        2023.000000         9.000000
#
#              Doors        Seats
# count  3607.000000  3607.000000
# mean      4.319102     4.899917
# std       0.986559     0.577079
# min       2.000000     2.000000
# 25%       3.000000     5.000000
# 50%       5.000000     5.000000
# 75%       5.000000     5.000000
# max       5.000000     7.000000

# %%
car_brand_df['Emission Class'].fillna('Euro 7')
# Out:
# 0       Euro 6
# 1       Euro 6
# 2       Euro 4
# 3       Euro 4
# 4       Euro 5
#          ...
# 3680    Euro 4
# 3681    Euro 5
# 3682    Euro 4
# 3683    Euro 6
# 3684    Euro 5
# Name: Emission Class, Length: 3607, dtype: object

# %%
car_brand_df
# Out:
#                       title  Price  Mileage(miles)  Registration_Year  \
# 0               SKODA FABIA   6900           70189               2016
# 1               SKODA FABIA   6900           70189               2016
# 2               SKODA FABIA   1990          150000               2007
# 3               SKODA FABIA   1995           84000               2008
# 4               SKODA FABIA   2495          124138               2011
# ...                     ...    ...             ...                ...
# 3680   MASERATI GRANTURISMO  16000           66000               2008
# 3681        MASERATI GHIBLI  13900           63000               2014
# 3682  MASERATI QUATTROPORTE  10000           72000               2009
# 3683      SSANGYONG KORANDO  12995           42771               2018
# 3684      SSANGYONG KORANDO   4277           82400               2013
#
#       Previous Owners Fuel type  Body type Engine    Gearbox  Doors  Seats  \
# ...

# %%
car_brand_df['Emission Class'].fillna('Euro 7', inplace=True) #NaN 값 살리려고 일부러 임의 값 설정

# %%
car_brand_df['Emission Class'].value_counts()
# Out:
# Euro 5    1256
# Euro 6    1109
# Euro 4    1067
# Euro 3     137
# Euro 2      23
# Euro 7      14
# Euro 1       1
# Name: Emission Class, dtype: int64

# %%
ttt = pd.DataFrame(car_brand_df['Emission Class'].str.split(expand= True),columns = [1])
#실행 안되면 행 하나 형태로 만든 뒤에 아래거 다시 실행.
ttt = ttt.rename(columns={ttt.columns[0]: 'Emission Class_Euro'})
ttt = ttt.astype(int)

# %%
ttt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3607 entries, 0 to 3684
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Emission Class_Euro  3607 non-null   int64
# dtypes: int64(1)
# memory usage: 56.4 KB

# %%
car_brand_df = pd.concat([car_brand_df, ttt], axis = 1)

# %%
car_brand_df.drop(['Emission Class'], axis = 1, inplace = True)

# %%
car_brand_df['Emission Class_Euro'].replace(7, np.nan, inplace = True)

# %%
car_brand_df #emission calss 수치화 끝
# Out:
#                       title  Price  Mileage(miles)  Registration_Year  \
# 0               SKODA FABIA   6900           70189               2016
# 1               SKODA FABIA   6900           70189               2016
# 2               SKODA FABIA   1990          150000               2007
# 3               SKODA FABIA   1995           84000               2008
# 4               SKODA FABIA   2495          124138               2011
# ...                     ...    ...             ...                ...
# 3680   MASERATI GRANTURISMO  16000           66000               2008
# 3681        MASERATI GHIBLI  13900           63000               2014
# 3682  MASERATI QUATTROPORTE  10000           72000               2009
# 3683      SSANGYONG KORANDO  12995           42771               2018
# 3684      SSANGYONG KORANDO   4277           82400               2013
#
#       Previous Owners Fuel type  Body type Engine    Gearbox  Doors  Seats  \
# ...

# %%
#car_brand_df[car_brand_df.isna()]
#이 코드에서 car_brand_df[조건]을 사용할 때, 조건이 True인 행만 가져오려면 모든 컬럼 값이 True여야 함.
#하지만 car_brand_df.isna()는 NaN이 아닌 값에 대해 False를 반환하므로, 모든 컬럼 값이 NaN인 행만 필터링됨.
#결과적으로 모든 값이 NaN인 행만 남게 됨.

# %%
car_brand_df['Engine'].value_counts()
# Out:
# 1.6L    733
# 2.0L    544
# 1.2L    518
# 1.4L    421
# 1.0L    325
# 1.5L    292
# 1.3L    166
# 1.8L    155
# 3.0L     77
# 2.2L     75
# 2.1L     63
# 1.1L     39
# 1.7L     34
# 1.9L     31
# 2.5L     30
# 2.4L     28
# 0.9L     15
# 2.7L     10
# 3.5L     10
# 3.2L      7
# 4.4L      5
# 3.7L      5
# 4.2L      4
# 5.0L      3
# 2.3L      3
# 2.8L      3
# 2.6L      2
# 4.3L      2
# 0.8L      2
# 5.5L      1
# 6.3L      1
# 3.1L      1
# 4.8L      1
# 3.3L      1
# Name: Engine, dtype: int64

# %%
pp = car_brand_df['Engine'].apply(lambda s: s[:-1] if isinstance(s, str) and s.endswith("L") else s)
#NaN 같은 문자열이 아닌 값이 있으면 .endswith("L")에서 에러가 발생할 수 있음
#따라서 isinstance(s, str)를 추가하여 안전하게 처리

# %%
pp = pd.DataFrame(pp)
#실행 안되면 행 하나 형태로 만든 뒤에 아래거 다시 실행.
ppp = pp.rename(columns={pp.columns[0]: 'Engine_L_'})

# %%
car_brand_df = pd.concat([car_brand_df, ppp], axis = 1)

# %%
car_brand_df.drop(['Engine'], axis = 1, inplace = True)

# %%
car_brand_df['Service history'].fillna('Unknown', inplace = True)

# %%
car_brand_df
# Out:
#                       title  Price  Mileage(miles)  Registration_Year  \
# 0               SKODA FABIA   6900           70189               2016
# 1               SKODA FABIA   6900           70189               2016
# 2               SKODA FABIA   1990          150000               2007
# 3               SKODA FABIA   1995           84000               2008
# 4               SKODA FABIA   2495          124138               2011
# ...                     ...    ...             ...                ...
# 3680   MASERATI GRANTURISMO  16000           66000               2008
# 3681        MASERATI GHIBLI  13900           63000               2014
# 3682  MASERATI QUATTROPORTE  10000           72000               2009
# 3683      SSANGYONG KORANDO  12995           42771               2018
# 3684      SSANGYONG KORANDO   4277           82400               2013
#
#       Previous Owners Fuel type  Body type    Gearbox  Doors  Seats  \
# ...
